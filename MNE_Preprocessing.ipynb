# %% [markdown]
# <a href="https://colab.research.google.com/github/abdipourasl/CNN---Scalogram/blob/main/MNE_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import cv2
import imghdr
from google.colab import drive
# %matplotlib inline
import os
import os.path as op
# !pip install mne
import mne
import numpy as np
import pandas as pd
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/')
data_dir= '/content/drive/My Drive/'
# Out:
# Collecting mne
#   Downloading mne-1.5.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 51.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from mne) (1.23.5)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from mne) (1.10.1)
# Requirement already satisfied: matplotlib>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.7.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (23.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.7.22)
# Installing collected packages: mne
# Successfully installed mne-1.5.1
# Mounted at /content/drive

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h1>EEG Preprocessing with MNE</h1>
# </div>

# %% [markdown]
# ### 1. Importing Raw  Data

# %% [markdown]
# >You need to provide your own EEG data with BrainVision format which have three files named  .vhdr, .vmrk and .eeg

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> You can change read_raw_brainvision() <a href="https://mne.tools/stable/auto_tutorials/io/plot_20_reading_eeg_data.html" title="Data EEG formats"> module based on your data format</a>
# </div>

# %%
examples_dir = os.path.join('/content/drive/My Drive/','OCD_subj46.EDF')  # Path to the raw EEG Data folder
raw = mne.io.read_raw_edf(os.path.join('/content/drive/My Drive/','OCD_subj46.EDF'))                                                         # Loading continuous data
print(raw)
# Out:
# Extracting EDF parameters from /content/drive/My Drive/OCD_subj46.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <RawEDF | OCD_subj46.EDF, 23 x 165500 (331.0 s), ~27 kB, data not loaded>

# %%
raw.crop(tmin=5., tmax=50.)
# Out:
# <RawEDF | OCD_subj46.EDF, 23 x 22501 (45.0 s), ~27 kB, data not loaded>

# %% [markdown]
# ### 2. Downsampling

# %%
raw.resample(250, npad="auto")    # set sampling frequency to 256 points per second
# Out:
# <RawEDF | OCD_subj46.EDF, 23 x 11250 (45.0 s), ~2.0 MB, data loaded>

# %% [markdown]
# ### 3. Channel Selection

# %%
raw.pick_channels(['Fp1','Fp2','F7','F3','F4','F8','T3','C3','C4','T4','T5','P3','P4','T6','O1','O2','Fz','Cz','Pz'],ordered=True)
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <RawEDF | OCD_subj46.EDF, 19 x 11250 (45.0 s), ~1.7 MB, data loaded>

# %%
print(raw.info["ch_names"])
print(raw)
# Out:
# ['Fp1', 'Fp2', 'F7', 'F3', 'F4', 'F8', 'T3', 'C3', 'C4', 'T4', 'T5', 'P3', 'P4', 'T6', 'O1', 'O2', 'Fz', 'Cz', 'Pz']
# <RawEDF | OCD_subj46.EDF, 19 x 11250 (45.0 s), ~1.7 MB, data loaded>

# %% [markdown]
# >according to the Nyquist frequency, sampling rate should be at least two times of frequency.
# Moreover, 128 points are suitable and 256 points are desirable

# %% [markdown]
# ### 4. Rereference

# %%
raw.set_eeg_reference('average', projection=True).apply_proj()  # re-referencing with the virtual average reference
# Out:
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# <RawEDF | OCD_subj46.EDF, 19 x 11250 (45.0 s), ~1.7 MB, data loaded>

# %% [markdown]
# ### 5. Clean Data - ASR

# %%
raw_uncleaned = raw.copy()

# %%
ssp_projectors = raw.info["projs"]
raw.del_proj()
# Out:
# <RawEDF | OCD_subj46.EDF, 19 x 11250 (45.0 s), ~1.7 MB, data loaded>

# %% [markdown]
# First of all, we initialize an instance of the `ASR` class, which stores predefined parameters (like the rejection threshold), the functional procedures as well as the parameters matrices that are used to transform data.
#
# If you are familiar with [scikit-learn](https://scikit-learn.org/stable/), you will notice that a lot of MNE's automated cleaning and decoding functions work similar to scikit learn and can usually be seamlessly integrated into sklearn pipelines (which is due to the fact that some of the MNE developers also work on sklearn). This is especially helpful for brain decoding and BCI applications.
#
# At initialization our ASR instance needs to know the sampling frequency of our raw data (which is required for multiple features of the algorithms). We also tell it to repair portions of data whose variance is 5 standard deviations larger than the reference data.

# %%
# !pip install -U autoreject
# !pip install https://api.github.com/repos/autoreject/autoreject/zipball/master
#python -c 'import autoreject'
from autoreject import AutoReject
ar = AutoReject()
epochs_clean = ar.fit_transform(epochs)  # doctest: +SKIP
from autoreject import get_rejection_threshold
reject = get_rejection_threshold(epochs)  # doctest: +SKIP
# Out:
# Requirement already satisfied: autoreject in /usr/local/lib/python3.10/dist-packages (0.5.dev2)
# Requirement already satisfied: numpy>=1.20.2 in /usr/local/lib/python3.10/dist-packages (from autoreject) (1.23.5)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from autoreject) (1.10.1)
# Requirement already satisfied: mne[hdf5]>=1.0 in /usr/local/lib/python3.10/dist-packages (from autoreject) (1.5.1)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from autoreject) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from autoreject) (1.3.2)
# Requirement already satisfied: matplotlib>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from autoreject) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject) (1.7.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject) (3.1.2)
# Requirement already satisfied: h5io in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject) (0.1.9)
# Requirement already satisfied: pymatreader in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject) (0.0.32)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->autoreject) (3.2.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne[hdf5]>=1.0->autoreject) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne[hdf5]>=1.0->autoreject) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.0->autoreject) (1.16.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from h5io->mne[hdf5]>=1.0->autoreject) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne[hdf5]>=1.0->autoreject) (2.1.3)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (from pymatreader->mne[hdf5]>=1.0->autoreject) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject) (2023.7.22)
# Collecting https://api.github.com/repos/autoreject/autoreject/zipball/master
#   Using cached https://api.github.com/repos/autoreject/autoreject/zipball/master
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.2 in /usr/local/lib/python3.10/dist-packages (from autoreject==0.5.dev2) (1.23.5)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from autoreject==0.5.dev2) (1.10.1)
# Requirement already satisfied: mne[hdf5]>=1.0 in /usr/local/lib/python3.10/dist-packages (from autoreject==0.5.dev2) (1.5.1)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from autoreject==0.5.dev2) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from autoreject==0.5.dev2) (1.3.2)
# Requirement already satisfied: matplotlib>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from autoreject==0.5.dev2) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4.0->autoreject==0.5.dev2) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject==0.5.dev2) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject==0.5.dev2) (1.7.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject==0.5.dev2) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject==0.5.dev2) (3.1.2)
# Requirement already satisfied: h5io in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject==0.5.dev2) (0.1.9)
# Requirement already satisfied: pymatreader in /usr/local/lib/python3.10/dist-packages (from mne[hdf5]>=1.0->autoreject==0.5.dev2) (0.0.32)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->autoreject==0.5.dev2) (3.2.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne[hdf5]>=1.0->autoreject==0.5.dev2) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne[hdf5]>=1.0->autoreject==0.5.dev2) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.0->autoreject==0.5.dev2) (1.16.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from h5io->mne[hdf5]>=1.0->autoreject==0.5.dev2) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne[hdf5]>=1.0->autoreject==0.5.dev2) (2.1.3)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (from pymatreader->mne[hdf5]>=1.0->autoreject==0.5.dev2) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject==0.5.dev2) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject==0.5.dev2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject==0.5.dev2) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne[hdf5]>=1.0->autoreject==0.5.dev2) (2023.7.22)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5772c7b39f66> in <cell line: 6>()
#       4 from autoreject import AutoReject
#       5 ar = AutoReject()
# ----> 6 epochs_clean = ar.fit_transform(epochs)  # doctest: +SKIP
#       7 from autoreject import get_rejection_threshold
#       8 reject = get_rejection_threshold(epochs)  # doctest: +SKIP
#
# NameError: name 'epochs' is not defined

# %%
# !pip install asrpy -q
from asrpy import ASR
asr = ASR(sfreq=raw.info["sfreq"], cutoff=5)

# %% [markdown]
# Now we fit our asr object to the data.
#
# We will use our entire raw data to fit. If your dataset is too large, you could also just use a fraction of the data for fitting. Theoretically, you could fit your cleaning algorithm to one dataset and then apply it to another, but this is very unusual and only makes sense for very specific experimental setups.

# %%
asr.fit(raw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1345bf5b021b> in <cell line: 1>()
# ----> 1 asr.fit(raw)
#
# NameError: name 'asr' is not defined

# %% [markdown]
# After our `asr` object was fitted to a certain dataset, we can apply it to our recorded raw data. The uncleaned data is transformed (/interpolated) according to the ASR procedure.

# %%
raw._data = asr.transform(raw)

# %%
scalings= {"eeg":2e-5}

print("Uncleaned data")
raw_uncleaned.plot(scalings=scalings);

print("Cleaned data")
raw._data.plot(start=0.25, scalings=scalings);
# Out:
# Uncleaned data
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Cleaned data
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ### 6. Filtering the data

# %%
raw.filter(1, 30, fir_design='firwin', picks=['eeg'])  # band-pass filter from 1 to 30 frequency over just
                                                       # EEG channel and not EEG channel
raw.plot_psd(fmax=100);
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 825 samples (3.300 s)
#
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# <ipython-input-27-194f3f2586e1>:3: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd(fmax=100);
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# >Lw-pass filter with 1 Hz cutoff frequency for removing low-frequency drifts.
#     High-pass filter with 30 Hz cutoff frequency for deteriorating the effect of
#     the AC power line frequency, cell phones, the geomagnetic field and so forth.
#     Therefore, a band-pass filter was used in the range 1Hz-30Hz with one step.
#     You can apply another band pass filter due to your own assumtions and hypotheses.
#     I recommend that band pass filtering would be better to occurr before the EEG
#     data epoching and artifact removal with ICA.

# %%
raw.notch_filter(freqs=[16.667, 50]); # bandstop the train and power grid
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 1651 samples (6.604 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s

# %%
raw.plot_psd(fmax=100);
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# <ipython-input-71-f37641293c7d>:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd(fmax=100);
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# ### 7. Visual Inspection

# %% [markdown]
# ###### 7.1 Plot continuous data

# %%
#%matplotlib qt
raw.plot()       # plot the EEG data. Use the '%matplotlib qt' to see
                 # the data in a bright way and move conveniently
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# >Use of visual inspection to reject some segments which have abnormal frequency,
#      signal discontinuous, abrupt jumping, irrelevant-task and son on.
#      Trace all EEG channels during time.
#      The best way to remove segtion of the data is deleting annotations in the segtion.
#      In addition, when you see irrelavant task or noise segemt in specefict channel,
#      you shoud remove the sement in all channels
#      Afterward, The instances of noisy segment which should be removed are created by
#      providing a EXCELL file with two columns of onsets and  offsets with descriptions
#      for each segment. The onsets and offsets are marked as seconds. onset refers to time
#      from start of the data. offset refers to time from end of the data

# %% [markdown]
# ###### 7.2 channel bad correction

# %%
#raw.info['bads'] = ['Fp1','Fp2','Fpz']         # Select bad channels visually to interpolate them with channels
                                               # Sleceted channels are not real
raw = raw.interpolate_bads(reset_bads=False)
# Out:
# <ipython-input-30-ad6fcc0c0626>:3: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   raw = raw.interpolate_bads(reset_bads=False)

# %% [markdown]
# ###### 7.3 Delete annotations

# %%
visual_inspection = pd.read_csv(examples_dir + "\\sub-005_visual_inspection.csv")  # Path to annotation folder
                                                                                  # remove each segment with start and end time
for i in range(visual_inspection.shape[0]):
    result = np.where((mne.events_from_annotations(raw)[0][:,0] > visual_inspection['Start'][i]*256) &
                      (mne.events_from_annotations(raw)[0][:,0] < visual_inspection['End'][i]*256));
    raw.annotations.delete(result)

# %%
raw.plot()    # Let's see the data again to be sure that the noisy segemnts have been deleted

# %% [markdown]
# ### 8. Segmenting continuous data into epochs and setting Ampilitude ceriteria

# %%
events_from_annot, event_dict = mne.events_from_annotations(raw)# Get events and event_id from an Annotations object.
event_dict = {'74':74, '75':75, '76':76}                        # Event dictionaries to extract epochs from continuous data,
reject_criteria = dict(eeg=100e-6)                              # Absolute Amplitude of each epoch sould be smaller than 100 μV
                                                                # tmin is start time before event, tmax is end time after event
                                                                # - 100 ms (baseline) of cue's onset to 600 ms
epochs = mne.Epochs(raw, events_from_annot, event_id=event_dict, tmin=-0.1, tmax=1.6,
                    reject=reject_criteria, baseline = (None,0), preload=True, picks=['eeg'])
